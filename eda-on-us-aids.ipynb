# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams["figure.figsize"]=(20,7)

# %%
aid = pd.read_csv('../input/us-foreign-aid-country-foreign-assistance/us_foreign_aid_country.csv')

# %%
aid
# Out:
#       country_code country_name  region_id         Region Name income_roup  \
# 0              ABW        Aruba          6  Western Hemisphere         HIC
# 1              ABW        Aruba          6  Western Hemisphere         HIC
# 2              ABW        Aruba          6  Western Hemisphere         HIC
# 3              ABW        Aruba          6  Western Hemisphere         HIC
# 4              ABW        Aruba          6  Western Hemisphere         HIC
# ...            ...          ...        ...                 ...         ...
# 21968          ZWE     Zimbabwe          5  Sub-Saharan Africa        LMIC
# 21969          ZWE     Zimbabwe          5  Sub-Saharan Africa        LMIC
# 21970          ZWE     Zimbabwe          5  Sub-Saharan Africa        LMIC
# 21971          ZWE     Zimbabwe          5  Sub-Saharan Africa        LMIC
# 21972          ZWE     Zimbabwe          5  Sub-Saharan Africa        LMIC
#
# ...

# %%
aid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21973 entries, 0 to 21972
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   country_code           21914 non-null  object
#  1   country_name           21973 non-null  object
#  2   region_id              21973 non-null  int64
#  3   Region Name            21973 non-null  object
#  4   income_roup            19764 non-null  object
#  5   income_group_name      19764 non-null  object
#  6   transaction_type_id    21973 non-null  int64
#  7   transaction_type_name  21973 non-null  object
#  8   fiscal_year            21973 non-null  object
#  9   current_amount         21973 non-null  int64
#  10  constant_amount        21973 non-null  int64
# dtypes: int64(4), object(7)
# memory usage: 1.8+ MB

# %%
sns.pairplot(aid)

# this will help us to see the pairwise relation of all the numerical attributes among
# different columns

# %%
# now let's see all the unique values of each column

# %%
aid['country_name'].unique()
# Out:
# array(['Aruba', 'Afghanistan', 'Angola', 'Anguilla', 'Albania',
#        'Asia, Middle East and North Africa Region',
#        'Netherlands Antilles (former)', 'United Arab Emirates',
#        'Argentina', 'Armenia', 'Asia Region', 'Antigua and Barbuda',
#        'Australia', 'Austria', 'Azerbaijan', 'Burundi', 'Belgium',
#        'Benin', 'Burkina Faso', 'Bangladesh', 'Bulgaria', 'Bahrain',
#        'Bahamas', 'Bosnia and Herzegovina', 'Belarus', 'Belize',
#        'Bermuda', 'Bolivia', 'Brazil', 'Barbados', 'Brunei', 'Bhutan',
#        'Botswana', 'Central African Republic', 'Canada',
#        'Central America and Caribbean Region', 'Switzerland', 'Chile',
#        'China (P.R.C.)', "Cote d'Ivoire", 'Cameroon',
#        'Central America Region', 'Congo (Kinshasa)',
#        'Congo (Brazzaville)', 'Cook Islands', 'Colombia', 'Comoros',
#        'Cabo Verde', 'Costa Rica', 'Caribbean Region', 'Kosovo', 'Cuba',
#        'Curacao', 'Cayman Islands', 'Cyprus', 'Czechia', 'Germany',
# ...

# %%
aid['Region Name'].unique()
# Out:
# array(['Western Hemisphere', 'South and Central Asia',
#        'Sub-Saharan Africa', 'Europe and Eurasia', 'World',
#        'Middle East and North Africa', 'East Asia and Oceania'],
#       dtype=object)

# %%
aid['income_group_name'].unique()
# Out:
# array(['High Income Country', 'Low Income Country',
#        'Lower Middle Income Country', nan, 'Upper Middle Income Country'],
#       dtype=object)

# %%
aid['transaction_type_name'].unique()
# Out:
# array(['Obligations', 'Disbursements', 'Appropriated and Planned',
#        "President's Budget Requests", 'Initial Allocations'], dtype=object)

# %%
aid['fiscal_year'].unique()
# Out:
# array(['1999', '2000', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2018', '2019', '2020', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '1950', '1951', '1952', '1953', '1954',
#        '1955', '1956', '1957', '1958', '1959', '1960', '1961', '1962',
#        '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970',
#        '1971', '1972', '1973', '1974', '1975', '1976', '1976tq', '1977',
#        '1978', '1979', '1985', '1986', '1987', '1988', '1989', '1990',
#        '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '2001', '2002', '2003', '2021', '2022', '1980', '1981', '1982',
#        '1983', '1984', '1946', '1947', '1948', '1949'], dtype=object)

# %%
aid['transaction_type_name'].value_counts().plot(kind='pie')

# this pie chart tells us about the type of transactions is actually distributed.
# Out:
# <AxesSubplot:ylabel='transaction_type_name'>

# %%
aid['fiscal_year'].value_counts().plot(kind='pie')

# this gives a distrubution of transactions in different fiscal years
# Out:
# <AxesSubplot:ylabel='fiscal_year'>

# %%
aid['Region Name'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Region Name'>

# %%
df = pd.DataFrame(aid)

# %%
df.head()
# Out:
#   country_code country_name  region_id         Region Name income_roup  \
# 0          ABW        Aruba          6  Western Hemisphere         HIC
# 1          ABW        Aruba          6  Western Hemisphere         HIC
# 2          ABW        Aruba          6  Western Hemisphere         HIC
# 3          ABW        Aruba          6  Western Hemisphere         HIC
# 4          ABW        Aruba          6  Western Hemisphere         HIC
#
#      income_group_name  transaction_type_id transaction_type_name fiscal_year  \
# 0  High Income Country                    2           Obligations        1999
# 1  High Income Country                    2           Obligations        2000
# 2  High Income Country                    2           Obligations        2004
# 3  High Income Country                    2           Obligations        2005
# 4  High Income Country                    2           Obligations        2006
#
#    current_amount  constant_amount
# ...

# %%
aid['transaction_type_name'].value_counts().plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
aid['transaction_type_name'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
aid['income_group_name'].value_counts().plot(kind='bar')

# this shows us that most of the aid given by the United States is given to Upper-Middle
# income countries.
# Out:
# <AxesSubplot:>

# %%
aid['Region Name'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.corr()

# from here we can see the correlation coefficients between the different numerical
# values of the columns

# we also observe that the constant amount have a high correlation with constant amount and
# vice versa, so let's see a scatter plot of these two columns
# Out:
#                      region_id  transaction_type_id  current_amount  \
# region_id             1.000000            -0.010056        0.083750
# transaction_type_id  -0.010056             1.000000        0.031754
# current_amount        0.083750             0.031754        1.000000
# constant_amount       0.052081             0.000386        0.916595
#
#                      constant_amount
# region_id                   0.052081
# transaction_type_id         0.000386
# current_amount              0.916595
# constant_amount             1.000000

# %%
plt.scatter(df['current_amount'], df['constant_amount'], c ="blue")

# as expected, the scatter plot also shows a positive correlation

# %% [markdown]
# Key takeaways:
# 1. The most of the aid given by the USA is to the Upper-Middle income countries while low income countries receive the lowest share
# 2. In the dataset, we found that a positive correlation exists between 'Current Amount' and 'Constant Amount'
# 3. Most of the aids were provoded out of obligations
# 4. A majority of aids were given in the sub-Saharan region, followed by the Western Hemisphere
